# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# 1) LOAD DATA
# ============================================
df = pd.read_csv("cellula toxic data.csv")

df["text"] = df["query"] + " " + df["image descriptions"]
texts = df["text"].astype(str).values
labels = df["Toxic Category"].astype(str).values

# Encode labels
le = LabelEncoder()
labels = le.fit_transform(labels)
num_classes = len(le.classes_)

# %%
# 2) TRAIN–TEST SPLIT
# ============================================
X_train, X_test, y_train, y_test = train_test_split(
    texts, labels, test_size=0.2, random_state=42
)

# %%
# 3) TOKENIZATION
# ============================================
max_words = 20000
max_len = 120

tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train)

X_train_pad = pad_sequences(tokenizer.texts_to_sequences(X_train), maxlen=max_len)
X_test_pad  = pad_sequences(tokenizer.texts_to_sequences(X_test),  maxlen=max_len)

# %%
# 4) CLASS WEIGHTS
# ============================================
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(labels),
    y=labels
)
class_weights = dict(enumerate(class_weights))
print("Class Weights:\n", class_weights)
# Out:
# Class Weights:
#  {0: 3.236245954692557, 1: 3.0303030303030303, 2: 1.1074197120708749, 3: 0.33500837520938026, 4: 2.898550724637681, 5: 2.9239766081871346, 6: 1.7006802721088434, 7: 0.4208754208754209, 8: 1.2165450121654502}

# %%
# 5) MODEL
# ============================================
embedding_dim = 128

model = Sequential([
    Embedding(max_words, embedding_dim, input_length=max_len),
    
    Bidirectional(LSTM(128, return_sequences=True, dropout=0.2)),
    Bidirectional(LSTM(64, dropout=0.2)),
    
    Dense(128, activation="relu"),
    Dropout(0.4),
    Dense(num_classes, activation="softmax")
])

optimizer = Adam(learning_rate=0.0005)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=optimizer,
    metrics=["accuracy"]
)

model.summary()
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# 6) CALLBACKS
# ============================================
checkpoint = ModelCheckpoint(
    "best_lstm.weights.h5",
    save_best_only=True,
    save_weights_only=True,
    monitor="val_loss",
    mode="min"
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=2
)

# %%
# 7) TRAIN
# ============================================
history = model.fit(
    X_train_pad, y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=32,
    class_weight=class_weights,
    callbacks=[checkpoint, early_stop, lr_scheduler]
)
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 38s 479ms/step - accuracy: 0.1620 - loss: 2.0453 - val_accuracy: 0.4021 - val_loss: 1.5640 - learning_rate: 5.0000e-04
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 42s 485ms/step - accuracy: 0.6583 - loss: 1.3621 - val_accuracy: 0.7708 - val_loss: 0.6106 - learning_rate: 5.0000e-04
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 472ms/step - accuracy: 0.7844 - loss: 0.8609 - val_accuracy: 0.9417 - val_loss: 0.3392 - learning_rate: 5.0000e-04
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 371ms/step - accuracy: 0.8969 - loss: 0.4148 - val_accuracy: 0.8958 - val_loss: 0.2651 - learning_rate: 5.0000e-04
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 26s 436ms/step - accuracy: 0.9370 - loss: 0.1949 - val_accuracy: 0.9438 - val_loss: 0.1840 - learning_rate: 5.0000e-04
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 342ms/step - accuracy: 0.9844 - loss: 0.0793 - val_accuracy: 0.8854 - val_loss: 0.2987 - learning_rate: 5.0000e-04
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 324ms/step - accuracy: 0.9875 - loss: 0.0830 - val_accuracy: 0.9146 - val_loss: 0.2573 - learning_rate: 5.0000e-04
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 331ms/step - accuracy: 0.9932 - loss: 0.0599 - val_accuracy: 0.9375 - val_loss: 0.2215 - learning_rate: 2.5000e-04

# %%
# Load best checkpoint
model.load_weights("best_lstm.weights.h5")

# %%
# 8) EVALUATE
# ============================================
y_pred = np.argmax(model.predict(X_test_pad), axis=1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

f1 = f1_score(y_test, y_pred, average="macro")
print("F1 Score:", f1)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step
#
# Classification Report:
#                            precision    recall  f1-score   support
#
# Child Sexual Exploitation       0.96      1.00      0.98        24
#                 Elections       1.00      1.00      1.00        20
#        Non-Violent Crimes       1.00      1.00      1.00        57
#                      Safe       0.93      0.96      0.94       187
#        Sex-Related Crimes       1.00      1.00      1.00        22
#       Suicide & Self-Harm       1.00      1.00      1.00        20
#            Unknown S-Type       0.77      0.64      0.70        36
#            Violent Crimes       1.00      1.00      1.00       175
#                    unsafe       1.00      1.00      1.00        59
#
#                  accuracy                           0.96       600
#                 macro avg       0.96      0.96      0.96       600
#              weighted avg       0.96      0.96      0.96       600
#
# F1 Score: 0.9579058403031264

# %%
# 9) CONFUSION MATRIX
# ============================================
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=le.classes_, yticklabels=le.classes_,
            cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
# 10) TRAINING CURVES
# ============================================
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss")
plt.legend(["Train", "Val"])

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")
plt.legend(["Train", "Val"])

plt.show()
